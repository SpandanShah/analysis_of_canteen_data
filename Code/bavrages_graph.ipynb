# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read form file in group_data folder
df = pd.read_csv('../Data/Group_data/weekdays_weekend_aug.csv')
df1 = pd.read_csv('../Data/Group_data/weekdays_weekend_sep.csv')
df2 = pd.read_csv('../Data/Group_data/weekdays_weekend_oct.csv')
df3 = pd.read_csv('../Data/Group_data/weekdays_weekend_nov.csv')
df4 = pd.read_csv('../Data/Group_data/weekdays_weekend_dec.csv')
df5 = pd.read_csv('../Data/Group_data/weekdays_weekend_jan.csv')
df
# Out:
#                                  Item name  Weekdays  Weekend
# 0                               Cafe Mocha       7.8        3
# 1                               Cappuccino      48.6        3
# 2                       Captain Cold Mocha      17.4        7
# 3                            Coke Zero Can      25.0       20
# 4                      Cold Caramel Coffee      21.4        5
# 5                              Cold Coffee     133.2       50
# 6                            Diet Coke Can      53.4        2
# 7                        Double Eye Opener       9.4        3
# 8                                Fanta Can      35.0       16
# 9                            Filter Coffee      22.6        2
# 10                           Glass of Coke     142.6       43
# 11                         Glass of Sprite      37.8       15
# 12                               Green Tea      12.6        1
# 13  Iced Coffee(Black hot Coffee With Ice)      32.8       10
# ...

# %%
# count all elemet of count
weekend_sum=df['Weekend'].sum()
# count all elemet of count
weekdays_sum=(df['Weekdays'].sum())* 2/5
# plot
plt.bar(['Weekdays','Weekends'],[weekdays_sum,weekend_sum])
plt.title('Weekdays vs Weekends of August')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()

# %%
# count all elemet of count
weekend_sum=df1['Weekend'].sum()
# count all elemet of count
weekdays_sum=(df1['Weekdays'].sum())* 2/5
# plot
plt.bar(['Weekdays','Weekends'],[weekdays_sum,weekend_sum])
plt.title('Weekdays vs Weekends of September')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()

# %%
# count all elemet of count
weekend_sum=df2['Weekend'].sum()
# count all elemet of count
weekdays_sum=(df2['Weekdays'].sum()) * 2/5
# plot
plt.bar(['Weekdays','Weekends'],[weekdays_sum,weekend_sum])
plt.title('Weekdays vs Weekends of October')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()

# %%
# count all elemet of count
weekend_sum=df3['Weekend'].sum()
# count all elemet of count
weekdays_sum=df3['Weekdays'].sum() * 2/5
# plot
plt.bar(['Weekdays','Weekends'],[weekdays_sum,weekend_sum])
plt.title('Weekdays vs Weekends of November')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()

# %%
# count all elemet of count
weekend_sum=df4['Weekend'].sum()
# count all elemet of count
weekdays_sum=df4['Weekdays'].sum() * 2/5
# plot
plt.bar(['Weekdays','Weekends'],[weekdays_sum,weekend_sum])
plt.title('Weekdays vs Weekends of December')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()

# %%
# count all elemet of count
weekend_sum=df5['Weekend'].sum()
# count all elemet of count
weekdays_sum=df5['Weekdays'].sum() * 2/5
# plot
plt.bar(['Weekdays','Weekends'],[weekdays_sum,weekend_sum])
plt.title('Weekdays vs Weekends of January')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()

# %%
# line chart of
